# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Katherine Hoeck**
# Data Scientist

# %% [markdown]
# *I am interested in data science because it is a powerful tool to understanding the world around us. I enjoy analyzing data to gain insight that could lead to innovative solutions to complex social issues.*

# %% [markdown]
# ### Print Hello World and compute the sum of 1+1

# %%
print("Hello World")
1+1
# Out:
# Hello World
# 2

# %% [markdown]
# Horizontal Rule
# ***

# %% [markdown]
# Ordered List
# 1. First ordered list item
#   * Bulleted sub list
# 2. Another item

# %% [markdown]
# Bulleted List
# * Bulleted list item
#   1. With ordered sub list
# * Another Item

# %% [markdown]
# Table
# | This   |  Is    |  A     |Table   |
# |:------:|:------:|:------:|:------:|
# | It     | has    | four   |columns |
# |Each    | column | is     |centered|
# | It     | has    | four   |rows    |

# %% [markdown]
# Link
# [Exploratory Data Analysis in Python](https://nbviewer.org/github/Tanu-N-Prabhu/Python/blob/master/Exploratory_data_Analysis.ipynb)

# %% [markdown]
# Image
# ![image.png](attachment:11e6d188-3faa-4932-9794-b257500dd1c4.png "Rho Meson Goes to the Beach")

# %% [markdown]
# Music Video
# <a href="http://www.youtube.com/watch?feature=player_embedded&v=234OiGtOvII
# " target="_blank"><img src="http://img.youtube.com/vi/234OiGtOvII/0.jpg"
# alt="Nobody" width="240" height="180" border="10" /></a>
